# %%
# !pip install numpy
# !pip install pandas
# !pip install Pyarrow
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit-learn
# !pip install klib
# !pip install flask
# Out:
# Requirement already satisfied: numpy in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (1.26.3)
# Requirement already satisfied: pandas in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: Pyarrow in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (15.0.0)
# Requirement already satisfied: numpy<2,>=1.16.6 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from Pyarrow) (1.26.3)
# Requirement already satisfied: matplotlib in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from seaborn) (1.26.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (1.4.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: klib in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (1.1.2)
# Requirement already satisfied: Jinja2<4.0.0,>=3.0.3 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from klib) (3.1.3)
# Requirement already satisfied: matplotlib<4.0.0,>=3.0.3 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from klib) (3.8.2)
# Requirement already satisfied: numpy<2.0.0,>=1.16.3 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from klib) (1.26.3)
# Requirement already satisfied: pandas<3.0,>=1.2 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from klib) (2.2.0)
# Requirement already satisfied: plotly<6.0.0,>=5.2.2 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from klib) (5.18.0)
# Requirement already satisfied: scipy<2.0.0,>=1.1.0 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from klib) (1.12.0)
# Requirement already satisfied: screeninfo<0.9.0,>=0.8.1 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from klib) (0.8.1)
# Requirement already satisfied: seaborn>=0.11.2 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from klib) (0.13.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from Jinja2<4.0.0,>=3.0.3->klib) (2.1.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from pandas<3.0,>=1.2->klib) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from pandas<3.0,>=1.2->klib) (2023.4)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from plotly<6.0.0,>=5.2.2->klib) (8.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.0.3->klib) (1.16.0)
# Requirement already satisfied: flask in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (3.0.1)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from flask) (3.0.1)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from flask) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from flask) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from flask) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from flask) (1.7.0)
# Requirement already satisfied: colorama in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\juelb\desktop\bostonhousing-randomforest\venv\lib\site-packages (from Jinja2>=3.1.2->flask) (2.1.4)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler 
from sklearn import datasets 
import klib

# %%
sns.set()

# %%
from sklearn.datasets import fetch_openml
boston_data = fetch_openml(name='boston', version=1, as_frame=True)

# %%
boston_data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
print(boston_data.DESCR)
# Out:
# **Author**:
# **Source**: Unknown - Date unknown
# **Please cite**:
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
# Variables in order:
# CRIM     per capita crime rate by town
# ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS    proportion of non-retail business acres per town
# CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# NOX      nitric oxides concentration (parts per 10 million)
# RM       average number of rooms per dwelling
# AGE      proportion of owner-occupied units built prior to 1940
# DIS      weighted distances to five Boston employment centres
# RAD      index of accessibility to radial highways
# TAX      full-value property-tax rate per $10,000
# PTRATIO  pupil-teacher ratio by town
# B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# LSTAT    % lower status of the population
# MEDV     Median value of owner-occupied homes in $1000's
#
#
# Information about the dataset
# CLASSTYPE: numeric
# CLASSINDEX: last
#
# Downloaded from openml.org.

# %%
boston = pd.DataFrame(data=np.c_[boston_data['data'], boston_data['target']], columns=list(boston_data['feature_names']) + ['target'])
boston.head()
# Out:
#       CRIM    ZN INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX PTRATIO  \
# 0  0.00632  18.0  2.31    0  0.538  6.575  65.2    4.09   1  296.0    15.3
# 1  0.02731   0.0  7.07    0  0.469  6.421  78.9  4.9671   2  242.0    17.8
# 2  0.02729   0.0  7.07    0  0.469  7.185  61.1  4.9671   2  242.0    17.8
# 3  0.03237   0.0  2.18    0  0.458  6.998  45.8  6.0622   3  222.0    18.7
# 4  0.06905   0.0  2.18    0  0.458  7.147  54.2  6.0622   3  222.0    18.7
#
#         B LSTAT target
# 0   396.9  4.98   24.0
# 1   396.9  9.14   21.6
# 2  392.83  4.03   34.7
# 3  394.63  2.94   33.4
# 4   396.9  5.33   36.2

# %%
boston.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'target'],
#       dtype='object')

# %%
boston.dtypes
# Out:
# CRIM       object
# ZN         object
# INDUS      object
# CHAS       object
# NOX        object
# RM         object
# AGE        object
# DIS        object
# RAD        object
# TAX        object
# PTRATIO    object
# B          object
# LSTAT      object
# target     object
# dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(boston.drop('target', axis=1),
                                                    boston[['target']], 
                                                    test_size=0.20, 
                                                    random_state=30)

# %%
categorical_column = ['CHAS', 'RAD']
numerical_column = ['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT']

# categorical_data = boston[categorical_column]
# numerical_data = boston[numerical_column]

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

# %%
num_pipeline = Pipeline([
    ('scaler', StandardScaler()) 
])

full_pipeline = ColumnTransformer([
    ('num_encoder', num_pipeline, numerical_column),
    ('categorical_encoder', OneHotEncoder(handle_unknown='ignore'), categorical_column)
])

# %%
y_train
# Out:
#     target
# 471   19.6
# 436    9.6
# 428   11.0
# 38    24.7
# 157   41.3
# ..     ...
# 500   16.8
# 301   22.0
# 429    9.5
# 421   14.2
# 293   23.9
#
# [404 rows x 1 columns]

# %%
prepared_x = full_pipeline.fit_transform(X_train)
prepared_y = num_pipeline.fit_transform(y_train)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rdm_reg = RandomForestRegressor(n_jobs=-1, criterion='squared_error')

# %%
rdm_reg.fit(prepared_x, prepared_y.ravel())
# Out:
# RandomForestRegressor(n_jobs=-1)

# %%
rdm_reg.score(prepared_x, prepared_y.ravel())
# Out:
# 0.9805760286133585

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(estimator=rdm_reg, X=prepared_x, y=prepared_y.ravel(), cv = 5)
# Out:
# array([0.81541659, 0.82247497, 0.89099879, 0.82111794, 0.8588614 ])

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = dict(n_estimators=[20, 50, 90, 110],
    criterion=['squared_error'],
    max_depth=range(18,30,2),
    min_samples_split=range(8,20,2),
    max_leaf_nodes=range(20,30,2),
    oob_score=[True],
    verbose=[2])

# %%
grid_search = GridSearchCV(estimator=rdm_reg, param_grid=param_grid, cv=5, n_jobs=-1)

# %%
grid_search.fit(prepared_x, prepared_y.ravel())
# Out:
# building tree 1 of 20building tree 2 of 20
#
# building tree 3 of 20
# building tree 4 of 20
# building tree 5 of 20
# building tree 6 of 20
# building tree 7 of 20
# building tree 8 of 20
# building tree 9 of 20
# building tree 10 of 20
# building tree 11 of 20
# building tree 12 of 20
# building tree 13 of 20
# building tree 14 of 20
# building tree 15 of 20
# building tree 16 of 20
# building tree 17 of 20
# building tree 18 of 20
# building tree 19 of 20
# building tree 20 of 20
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    0.0s finished
# GridSearchCV(cv=5, estimator=RandomForestRegressor(n_jobs=-1), n_jobs=-1,
#              param_grid={'criterion': ['squared_error'],
#                          'max_depth': range(18, 30, 2),
#                          'max_leaf_nodes': range(20, 30, 2),
#                          'min_samples_split': range(8, 20, 2),
#                          'n_estimators': [20, 50, 90, 110], 'oob_score': [True],
#                          'verbose': [2]})

# %%
best_clf = grid_search.best_estimator_
best_clf
# Out:
# RandomForestRegressor(max_depth=22, max_leaf_nodes=26, min_samples_split=8,
#                       n_estimators=20, n_jobs=-1, oob_score=True, verbose=2)

# %%
cross_val_score(estimator=best_clf, X=prepared_x, y=prepared_y.ravel(), cv = 5)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=16)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done  11 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=16)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=16)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done  11 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=16)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=16)]: Using backend ThreadingBackend with 16 concurrent workers.
# building tree 1 of 20
# building tree 2 of 20
# building tree 3 of 20
# building tree 4 of 20
# building tree 5 of 20
# building tree 6 of 20
# building tree 7 of 20
# building tree 8 of 20
# building tree 9 of 20
# building tree 10 of 20
# building tree 11 of 20
# building tree 12 of 20
# building tree 13 of 20
# building tree 14 of 20
# building tree 15 of 20
# building tree 16 of 20
# building tree 17 of 20
# building tree 18 of 20
# building tree 19 of 20
# building tree 20 of 20
# building tree 1 of 20
# building tree 2 of 20
# building tree 3 of 20
# building tree 4 of 20
# building tree 5 of 20
# building tree 6 of 20
# building tree 7 of 20
# building tree 8 of 20
# building tree 9 of 20
# building tree 10 of 20
# building tree 11 of 20
# building tree 12 of 20
# building tree 13 of 20
# building tree 14 of 20
# building tree 15 of 20
# building tree 16 of 20
# building tree 17 of 20
# building tree 18 of 20
# building tree 19 of 20
# building tree 20 of 20
# building tree 1 of 20
# building tree 2 of 20
# building tree 3 of 20
# building tree 4 of 20
# building tree 5 of 20
# building tree 6 of 20
# building tree 7 of 20
# building tree 8 of 20
# building tree 9 of 20
# building tree 10 of 20
# building tree 11 of 20
# building tree 12 of 20
# building tree 13 of 20
# building tree 14 of 20
# building tree 15 of 20
# building tree 16 of 20
# building tree 17 of 20
# building tree 18 of 20
# building tree 19 of 20
# building tree 20 of 20
# building tree 1 of 20
# building tree 2 of 20
# building tree 3 of 20
# building tree 4 of 20
# building tree 5 of 20
# building tree 6 of 20
# building tree 7 of 20
# building tree 8 of 20
# building tree 9 of 20
# building tree 10 of 20
# building tree 11 of 20
# building tree 12 of 20
# building tree 13 of 20
# building tree 14 of 20
# building tree 15 of 20
# building tree 16 of 20
# building tree 17 of 20
# building tree 18 of 20
# building tree 19 of 20
# building tree 20 of 20
# building tree 1 of 20
# building tree 2 of 20
# building tree 3 of 20
# building tree 4 of 20
# building tree 5 of 20
# building tree 6 of 20
# building tree 7 of 20
# building tree 8 of 20
# building tree 9 of 20
# building tree 10 of 20
# building tree 11 of 20
# building tree 12 of 20
# building tree 13 of 20
# building tree 14 of 20
# building tree 15 of 20
# building tree 16 of 20
# building tree 17 of 20
# building tree 18 of 20
# building tree 19 of 20
# building tree 20 of 20
# [Parallel(n_jobs=16)]: Done  11 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=16)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=16)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done  11 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=16)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=16)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done  11 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=16)]: Done  20 out of  20 | elapsed:    0.0s finished
# array([0.78461505, 0.84584012, 0.88419543, 0.79660985, 0.87937621])

# %%
# Scores of the random forest with default parameters - 
    # array([0.80675763, 0.8185184 , 0.89299855, 0.82498718, 0.86285874])
    
# Scores of the random forest with defined parameters
    # array([0.79778342, 0.81371299, 0.88251366, 0.7969549 , 0.86269461])
    
# hence we will use random forest with default parameters for our model

# %% [markdown]
# ## Checking Our Model on Test Data

# %%
prepared_test_x = full_pipeline.transform(X_test)
prepared_test_y = num_pipeline.transform(y_test)

# %%
cross_val_score(estimator=rdm_reg, X=prepared_test_x, y=prepared_test_y.ravel(), cv = 5)
# Out:
# array([0.76043423, 0.24807467, 0.87801382, 0.83668737, 0.85279745])

# %%
from sklearn.metrics import mean_squared_error

# %%
y_pred = rdm_reg.predict(prepared_test_x)
y_pred
# Out:
# array([-3.65766932e-01, -1.39401736e+00, -2.77905747e-01,  6.03662967e-01,
#        -6.94823965e-01, -3.50454586e-01,  5.09400814e-02,  2.39151136e+00,
#        -7.88070872e-01,  1.52635179e-01,  3.80525127e-01,  6.87511262e-01,
#        -6.44134820e-01,  5.08198411e-01, -7.31679198e-01,  4.08509759e-01,
#        -1.13592513e+00,  1.64462646e-01, -5.34836351e-01,  3.33044830e-02,
#        -2.31546300e-01, -8.70757540e-01,  3.78835489e-01, -2.95646948e-01,
#        -1.33139515e+00, -8.32107067e-01, -2.35664793e-01, -1.14205007e+00,
#        -8.08346530e-01, -8.99903798e-01, -7.70540876e-01, -2.77272133e-01,
#         1.07813449e+00,  9.80387454e-02, -2.17184376e-01, -1.92684622e-01,
#        -8.67800673e-01, -1.38827405e-01, -3.35353445e-01, -2.75160085e-01,
#        -3.46652900e-01, -3.22469954e-01,  2.61295956e+00,  1.14618320e-01,
#        -8.28581411e-02, -2.87832371e-01, -2.36509612e-01, -2.94590924e-01,
#        -2.59742137e-01, -5.13504669e-01, -6.31462534e-01, -5.05267683e-01,
#        -2.08736185e-01,  2.70804248e-01,  5.05769556e-01,  3.60501451e-02,
#         2.76977910e+00,  6.07887063e-01, -3.67350968e-01,  1.44351874e+00,
#        -2.33024733e-01, -1.08460237e+00,  2.65629731e-01, -2.66289485e-01,
#        -1.30446654e+00, -1.28989341e+00, -8.28938995e-01,  7.25885705e-02,
#         2.09043895e+00,  1.40349544e+00, -7.79094669e-01,  2.46938109e-01,
#        -1.85926069e-01,  3.03118578e-01,  4.82220224e-01, -7.47267574e-02,
#        -1.18017253e+00, -2.47914670e-01,  2.50936362e-04,  6.73254940e-01,
#        -3.81501687e-01, -1.94163055e-01,  8.06143518e-02, -1.36609755e-01,
#         2.26662451e-01,  1.38047412e+00,  2.33247962e+00,  7.37038780e-01,
#        -4.65877994e-01, -7.17422876e-01,  6.45270307e-01,  5.12568886e-02,
#        -5.69579536e-01,  9.55952526e-01, -8.73080792e-01, -4.16878487e-01,
#        -8.36859174e-01,  1.30201154e+00, -3.13071342e-01,  9.07797838e-01,
#        -1.29745600e-01, -7.53961301e-01])

# %%
np.sqrt(mean_squared_error(y_pred, prepared_test_y))
# Out:
# 0.27491752633270145

# %%
import joblib
import os

# %%
DIR = 'model'

if not os.path.isdir(DIR):
    os.mkdir(DIR)

# %%
joblib.dump(num_pipeline, os.path.join(DIR, 'num_pipeline.pkl'))
joblib.dump(full_pipeline, os.path.join(DIR, 'full_pipeline.pkl'))
joblib.dump(best_clf, os.path.join(DIR, 'random_forest.pkl'))
# Out:
# ['model\\random_forest.pkl']
